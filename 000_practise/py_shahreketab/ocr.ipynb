# %%
# !conda install -c mcs07 tesseract
# !conda install -c jim-hart pytesseract
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/506 [00:00<?, ?it/s]
# Examining pycurl:   0%|          | 0/506 [00:00<?, ?it/s]
# Examining anaconda-navigator==2.5.1:   0%|          | 1/506 [00:00<01:03,  7.95it/s]
# Examining anaconda-navigator==2.5.1:   0%|          | 2/506 [00:00<00:31, 15.91it/s]
# Examining imageio:   0%|          | 2/506 [00:00<00:31, 15.91it/s]
# Examining libffi:   1%|          | 3/506 [00:01<00:31, 15.91it/s]
# Examining libffi:   1%|          | 4/506 [00:01<03:45,  2.23it/s]
# Examining mdurl:   1%|          | 4/506 [00:01<03:45,  2.23it/s]
# Examining pexpect:   1%|          | 5/506 [00:01<03:44,  2.23it/s]
# Examining sqlite:   1%|1         | 6/506 [00:01<03:44,  2.23it/s]
# Examining llvmlite:   1%|1         | 7/506 [00:01<03:43,  2.23it/s]
# Examining conda-verify:   2%|1         | 8/506 [00:01<03:43,  2.23it/s]
# Examining conda-verify:   2%|1         | 9/506 [00:01<01:22,  5.99it/s]
# Examining cryptography:   2%|1         | 9/506 [00:01<01:22,  5.99it/s]
# Examining glob2:   2%|1         | 10/506 [00:02<01:22,  5.99it/s]
# Examining glob2:   2%|2         | 11/506 [00:02<02:12,  3.74it/s]
# Examining mathjax:   2%|2         | 11/506 [00:02<02:12,  3.74it/s]
# Examining plotly:   2%|2         | 12/506 [00:02<02:12,  3.74it/s]
# Examining typing-extensions:   3%|2         | 13/506 [00:03<02:11,  3.74it/s]
# Examining typing-extensions:   3%|2         | 14/506 [00:03<02:32,  3.22it/s]
# Examining attrs:   3%|2         | 14/506 [00:03<02:32,  3.22it/s]
# Examining libxslt:   3%|2         | 15/506 [00:04<02:32,  3.22it/s]
# Examining libxslt:   3%|3         | 16/506 [00:04<02:04,  3.93it/s]
# Examining python-kaleido:   3%|3         | 16/506 [00:04<02:04,  3.93it/s]
# Examining python-kaleido:   3%|3         | 17/506 [00:04<02:23,  3.42it/s]
# Examining cssselect:   3%|3         | 17/506 [00:04<02:23,  3.42it/s]
# Examining multidict:   4%|3         | 18/506 [00:04<02:22,  3.42it/s]
# Examining twisted:   4%|3         | 19/506 [00:04<02:22,  3.42it/s]
# Examining twisted:   4%|3         | 20/506 [00:04<01:32,  5.23it/s]
# Examining pytables:   4%|3         | 20/506 [00:05<01:32,  5.23it/s]
# Examining wheel:   4%|4         | 21/506 [00:07<01:32,  5.23it/s]
# Examining wheel:   4%|4         | 22/506 [00:07<04:14,  1.90it/s]
# Examining certifi:   4%|4         | 22/506 [00:07<04:14,  1.90it/s]
# Examining certifi:   5%|4         | 23/506 [00:07<04:06,  1.96it/s]
# Examining libwebp-base:   5%|4         | 23/506 [00:08<04:06,  1.96it/s]
# Examining libwebp-base:   5%|4         | 24/506 [00:08<03:34,  2.25it/s]
# Examining black:   5%|4         | 24/506 [00:08<03:34,  2.25it/s]
# Examining conda-libmamba-solver:   5%|4         | 25/506 [00:08<03:33,  2.25it/s]
# Examining xyzservices:   5%|5         | 26/506 [00:08<03:33,  2.25it/s]
# Examining xyzservices:   5%|5         | 27/506 [00:08<02:32,  3.14it/s]
# Examining hvplot:   5%|5         | 27/506 [00:08<02:32,  3.14it/s]
# Examining aiofiles:   6%|5         | 28/506 [00:10<02:32,  3.14it/s]
# Examining aiofiles:   6%|5         | 29/506 [00:10<03:52,  2.05it/s]
# Examining pycodestyle:   6%|5         | 29/506 [00:10<03:52,  2.05it/s]
# Examining tesseract:   6%|5         | 30/506 [00:10<03:51,  2.05it/s]
# Examining openpyxl:   6%|6         | 31/506 [00:10<03:51,  2.05it/s]
# Examining openpyxl:   6%|6         | 32/506 [00:10<02:29,  3.17it/s]
# Examining matplotlib-base:   6%|6         | 32/506 [00:10<02:29,  3.17it/s]
# Examining matplotlib-base:   7%|6         | 33/506 [00:10<02:21,  3.35it/s]
# Examining anaconda-catalogs:   7%|6         | 33/506 [00:12<02:21,  3.35it/s]
# Examining anaconda-catalogs:   7%|6         | 34/506 [00:12<04:53,  1.61it/s]
# Examining aws-c-event-stream:   7%|6         | 34/506 [00:12<04:53,  1.61it/s]
# Examining python-fastjsonschema:   7%|6         | 35/506 [00:12<04:52,  1.61it/s]
# Examining nbclassic:   7%|7         | 36/506 [00:12<04:51,  1.61it/s]
# Examining nbclassic:   7%|7         | 37/506 [00:12<02:51,  2.73it/s]
# Examining pytz:   7%|7         | 37/506 [00:13<02:51,  2.73it/s]
# Examining click:   8%|7         | 38/506 [00:13<02:51,  2.73it/s]
# Examining click:   8%|7         | 39/506 [00:13<03:13,  2.42it/s]
# Examining stack_data:   8%|7         | 39/506 [00:14<03:13,  2.42it/s]
# Examining aiosqlite:   8%|7         | 40/506 [00:14<03:12,  2.42it/s]
# Examining isort:   8%|8         | 41/506 [00:14<03:12,  2.42it/s]
# Examining isort:   8%|8         | 42/506 [00:14<02:03,  3.74it/s]
# Examining conda-index:   8%|8         | 42/506 [00:14<02:03,  3.74it/s]
# Examining jupyter_console:   8%|8         | 43/506 [00:14<02:03,  3.74it/s]
# Examining jupyter_console:   9%|8         | 44/506 [00:14<02:12,  3.48it/s]
# Examining pyrsistent:   9%|8         | 44/506 [00:15<02:12,  3.48it/s]
# Examining beautifulsoup4:   9%|8         | 45/506 [00:15<02:12,  3.48it/s]
# Examining beautifulsoup4:   9%|9         | 46/506 [00:15<02:35,  2.97it/s]
# Examining anaconda-project:   9%|9         | 46/506 [00:15<02:35,  2.97it/s]
# Examining anaconda-project:   9%|9         | 47/506 [00:15<02:17,  3.34it/s]
# Examining jupyter_ydoc:   9%|9         | 47/506 [00:16<02:17,  3.34it/s]
# Examining jupyter_ydoc:   9%|9         | 48/506 [00:16<02:40,  2.85it/s]
# Examining krb5:   9%|9         | 48/506 [00:16<02:40,  2.85it/s]
# Examining pydocstyle:  10%|9         | 49/506 [00:16<02:40,  2.85it/s]
# Examining vc:  10%|9         | 50/506 [00:16<02:39,  2.85it/s]
# Examining python-lsp-server:  10%|#         | 51/506 [00:16<02:39,  2.85it/s]
# Examining greenlet:  90%|######### | 457/506 [03:20<00:08,  5.92it/s]
# Examining greenlet:  91%|######### | 458/506 [03:20<00:13,  3.48it/s]
# Examining itsdangerous:  91%|######### | 458/506 [03:20<00:13,  3.48it/s]
# Examining @/win-64::__win==0=0:  91%|######### | 459/506 [03:20<00:13,  3.48it/s]
# Examining @/win-64::__win==0=0:  91%|######### | 460/506 [03:20<00:10,  4.39it/s]
# Examining imagesize:  91%|######### | 460/506 [03:20<00:10,  4.39it/s]
# Examining graphviz:  91%|#########1| 461/506 [03:20<00:10,  4.39it/s]
# Examining patsy:  91%|#########1| 462/506 [03:20<00:10,  4.39it/s]
# Examining locket:  92%|#########1| 463/506 [03:21<00:09,  4.39it/s]
# Examining locket:  92%|#########1| 464/506 [03:21<00:09,  4.39it/s]
# Examining babel:  92%|#########1| 464/506 [03:21<00:09,  4.39it/s]
# Examining python=3.11:  92%|#########1| 465/506 [03:21<00:09,  4.39it/s]
# Examining python=3.11:  92%|#########2| 466/506 [03:21<00:07,  5.25it/s]
# Examining win_inet_pton:  92%|#########2| 466/506 [03:21<00:07,  5.25it/s]
# Examining pkce:  92%|#########2| 467/506 [03:21<00:07,  5.25it/s]
# Examining pyodbc:  92%|#########2| 468/506 [03:21<00:07,  5.25it/s]
# ...
# conda-libmamba-solver -> libmambapy[version='0.22.*|>=0.23|>=1.0.0|>=1.4.1|>=1.5.1|>=1.5.3']
#
# Package y-py conflicts for:
# jupyter_server_ydoc -> jupyter_ydoc[version='>=0.2.0,<0.4.0'] -> y-py[version='>=0.5.3,<0.6.0']
# jupyterlab -> jupyter_ydoc[version='>=0.2.3,<0.3'] -> y-py[version='>=0.5.3,<0.6.0']
# ypy-websocket -> y-py[version='>=0.5.3,<0.6.0']
# jupyter_ydoc -> y-py[version='>=0.5.3,<0.6.0']
#
# Package aom conflicts for:
# libavif -> aom[version='>=3.6.0,<3.7.0a0']
# imagecodecs -> libavif[version='>=0.11.1,<0.11.2.0a0'] -> aom[version='>=3.6.0,<3.7.0a0']
#
# Package xarray conflicts for:
# datashader -> xarray[version='>=0.9.6']
# _anaconda_depends -> xarray
# _anaconda_depends -> datashader -> xarray[version='>=0.9.6']
#
# Package websocket-client conflicts for:
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> websocket-client
# _anaconda_depends -> websocket-client
# jupyter_server_fileid -> jupyter_server[version='>=1.15,<3'] -> websocket-client
# nbclassic -> jupyter_server[version='>=1.8'] -> websocket-client
# jupyterlab -> jupyter_server[version='>=2.4.0,<3'] -> websocket-client
# jupyter_server -> websocket-client
# jupyterlab_server -> jupyter_server[version='>=1.21,<3'] -> websocket-client
# notebook -> jupyter_server[version='>=2.4.0,<3'] -> websocket-client
#
# Package qtawesome conflicts for:
# _anaconda_depends -> qtawesome
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2|>=1.2.1']
# _anaconda_depends -> spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2|>=1.2.1']
#
# Package pyjwt conflicts for:
# _anaconda_depends -> anaconda-navigator -> pyjwt[version='>=2.1.0']
# anaconda-cloud-auth -> pyjwt
# anaconda-navigator==2.5.1 -> anaconda-cloud-auth[version='>=0.1.3'] -> pyjwt
# anaconda-navigator==2.5.1 -> pyjwt[version='>=2.1.0']
#
# Package c-blosc2 conflicts for:
# pytables -> c-blosc2[version='>=2.8.0,<3.0a0']
# _anaconda_depends -> pytables -> c-blosc2[version='>=2.8.0,<3.0a0']
#
# Package winpty conflicts for:
# jupyter_server -> pywinpty -> winpty[version='>=0.4.3,<1.0a0']
# terminado -> pywinpty[version='>=1.1.0'] -> winpty[version='>=0.4.3,<1.0a0']
# _anaconda_depends -> winpty
# pywinpty -> winpty[version='>=0.4.3,<1.0a0']
# _anaconda_depends -> pywinpty -> winpty[version='>=0.4.3,<1.0a0']
#
# Package rich conflicts for:
# _anaconda_depends -> cookiecutter -> rich
# attrs -> hypothesis -> rich[version='>=9.0.0']
# spyder -> cookiecutter[version='>=1.6.0'] -> rich
# cookiecutter -> rich
#
# Package pydocstyle conflicts for:
# python-lsp-server -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# _anaconda_depends -> python-lsp-server -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# python-lsp-black -> python-lsp-server[version='>=1.4.0'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# spyder -> python-lsp-server[version='>=1.7.2,<1.8.0'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# _anaconda_depends -> pydocstyle
#
# Package libgd conflicts for:
# pydotplus -> graphviz -> libgd[version='>=2.3.3,<2.4.0a0']
# graphviz -> libgd[version='>=2.3.3,<2.4.0a0']
#
# Package brotli-bin conflicts for:
# brotli -> brotli-bin==1.0.9=h2bbff1b_7
# arrow-cpp -> brotli[version='>=1.0.9,<2.0a0'] -> brotli-bin==1.0.9=h2bbff1b_7
# imagecodecs -> brotli[version='>=1.0.9,<1.1.0a0'] -> brotli-bin==1.0.9=h2bbff1b_7
# _anaconda_depends -> brotli -> brotli-bin==1.0.9=h2bbff1b_7
# fonttools -> brotli[version='>=1.0.1'] -> brotli-bin==1.0.9=h2bbff1b_7
#
# Package curl conflicts for:
# _anaconda_depends -> curl
# _anaconda_depends -> pycurl -> curl[version='7.55.*|>=7.55.1,<9.0a0']
#
# Package pywin32-ctypes conflicts for:
# _anaconda_depends -> pywin32-ctypes
# keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1|>=0.2.0']
# anaconda-cloud-auth -> keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1|>=0.2.0']
# spyder -> keyring[version='>=17.0.0'] -> pywin32-ctypes[version='!=0.1.0,!=0.1.1|>=0.2.0']
# _anaconda_depends -> keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1|>=0.2.0']
#
# Package queuelib conflicts for:
# scrapy -> queuelib[version='>=1.4.2']
# _anaconda_depends -> queuelib
# _anaconda_depends -> scrapy -> queuelib[version='>=1.4.2']
#
# Package three-merge conflicts for:
# _anaconda_depends -> three-merge
# spyder -> three-merge[version='>=0.1.1']
# _anaconda_depends -> spyder -> three-merge[version='>=0.1.1']
#
# Package tokenizers conflicts for:
# transformers -> tokenizers[version='>=0.10.1,<0.11|>=0.11.1,!=0.11.3,<0.13|>=0.11.1,!=0.11.3|>=0.11.1,!=0.11.3,<0.14']
# _anaconda_depends -> transformers -> tokenizers[version='>=0.10.1,<0.11|>=0.11.1,!=0.11.3,<0.13|>=0.11.1,!=0.11.3|>=0.11.1,!=0.11.3,<0.14']
#
# Package mdurl conflicts for:
# markdown-it-py -> mdurl[version='>=0.1,<1']
# mdit-py-plugins -> markdown-it-py[version='>=1.0.0,<3.0.0'] -> mdurl[version='>=0.1,<1']
# panel -> markdown-it-py -> mdurl[version='>=0.1,<1']
#
# Package libevent conflicts for:
# libthrift -> libevent
# arrow-cpp -> libthrift[version='>=0.15.0,<0.16.0a0'] -> libevent
#
# Package sphinxcontrib-devhelp conflicts for:
# numpydoc -> sphinx[version='>=4.2'] -> sphinxcontrib-devhelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-devhelp
# _anaconda_depends -> sphinxcontrib-devhelp
# sphinx -> sphinxcontrib-devhelp
#
# Package mathjax conflicts for:
# kaleido-core -> mathjax=2.7
# python-kaleido -> kaleido-core=0.2.1 -> mathjax=2.7
#
# Package m2w64-gmp conflicts for:
# pywinpty -> m2w64-gcc-libs -> m2w64-gmp
# _anaconda_depends -> m2w64-gmp
# libffi -> m2w64-gcc-libs -> m2w64-gmp
#
# Package whatthepatch conflicts for:
# python-lsp-black -> python-lsp-server[version='>=1.4.0'] -> whatthepatch[version='>=1.0.2,<2.0.0']
# spyder -> python-lsp-server[version='>=1.7.2,<1.8.0'] -> whatthepatch[version='>=1.0.2,<2.0.0']
# python-lsp-server -> whatthepatch[version='>=1.0.2,<2.0.0']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> whatthepatch[version='>=1.0.2,<2.0.0']
# _anaconda_depends -> python-lsp-server -> whatthepatch[version='>=1.0.2,<2.0.0']
#
# Package unidecode conflicts for:
# cookiecutter -> python-slugify[version='>=4.0.0'] -> unidecode[version='>=1.1.1']
# _anaconda_depends -> unidecode
# _anaconda_depends -> python-slugify -> unidecode[version='>=0.04.16|>=1.1.1']
# python-slugify -> unidecode[version='>=0.04.16|>=1.1.1']
#
# Package intake conflicts for:
# anaconda-catalogs -> intake
# _anaconda_depends -> intake
#
# Package boto3 conflicts for:
# _anaconda_depends -> boto3
# s3fs -> boto3
# gensim -> smart_open[version='>=1.8.1'] -> boto3
# transformers -> boto3
# smart_open -> boto3
#
# Package libsolv conflicts for:
# conda-libmamba-solver -> libmambapy[version='>=0.23'] -> libsolv[version='>=0.7.20,<0.8.0a0']
# libmamba -> libsolv[version='>=0.7.20,<0.8.0a0|>=0.7.22|>=0.7.22,<0.8.0a0|>=0.7.24,<0.8.0a0']
# libmambapy -> libmamba==1.5.3=hcd6fe79_0 -> libsolv[version='>=0.7.22|>=0.7.22,<0.8.0a0|>=0.7.24,<0.8.0a0']
# libmambapy -> libsolv[version='>=0.7.20,<0.8.0a0']
#
# Package aioitertools conflicts for:
# aiobotocore -> aioitertools[version='>=0.5.1|>=0.5.1,<1.0.0']
# s3fs -> aiobotocore[version='>=2.7.0,<2.8.0'] -> aioitertools[version='>=0.5.1|>=0.5.1,<1.0.0']
#
# Package numba conflicts for:
# _anaconda_depends -> datashader -> numba[version='>=0.35.0|>=0.37.0|>=0.37.0,!=0.49.*,!=0.50.*|>=0.51|>=0.37.0,<0.49']
# datashader -> numba[version='>=0.35.0|>=0.37.0|>=0.37.0,!=0.49.*,!=0.50.*|>=0.51|>=0.37.0,<0.49']
# _anaconda_depends -> numba
#
# Package jupyter_server_fileid conflicts for:
# jupyterlab -> jupyter_server_ydoc[version='>=0.8.0,<0.9.0'] -> jupyter_server_fileid[version='>=0.6.0,<1']
# jupyter_server_ydoc -> jupyter_server_fileid[version='>=0.6.0,<1']
#
# Package xxhash conflicts for:
# python-xxhash -> xxhash[version='>=0.8.0,<0.8.1.0a0']
# datasets -> python-xxhash -> xxhash[version='>=0.8.0,<0.8.1.0a0']
#
# Package backports.weakref conflicts for:
# _anaconda_depends -> backports.weakref
# conda-verify -> backports.tempfile -> backports.weakref
# backports.tempfile -> backports.weakref
#
# Package yaml-cpp conflicts for:
# libmambapy -> yaml-cpp[version='>=0.7.0,<0.8.0a0|>=0.8.0,<0.9.0a0']
# libmamba -> yaml-cpp[version='>=0.7.0,<0.8.0a0|>=0.8.0,<0.9.0a0']
# conda-libmamba-solver -> libmambapy[version='>=1.5.3'] -> yaml-cpp[version='>=0.7.0,<0.8.0a0|>=0.8.0,<0.9.0a0']
#
# Package python-lmdb conflicts for:
# zict -> python-lmdb
# _anaconda_depends -> zict -> python-lmdb
# distributed -> zict[version='>=3.0.0'] -> python-lmdb
#
# Package threadpoolctl conflicts for:
# imbalanced-learn -> scikit-learn[version='>=1.0.2'] -> threadpoolctl[version='>=2.0.0']
# _anaconda_depends -> scikit-learn -> threadpoolctl[version='>=2.0.0']
# nltk -> scikit-learn -> threadpoolctl[version='>=2.0.0']
# scikit-learn-intelex -> scikit-learn[version='>=0.24'] -> threadpoolctl[version='>=2.0.0']
# scikit-learn -> threadpoolctl[version='>=2.0.0']
# _anaconda_depends -> threadpoolctl
#
# Package ypy-websocket conflicts for:
# jupyterlab -> jupyter_server_ydoc[version='>=0.8.0,<0.9.0'] -> ypy-websocket[version='>=0.8.2,<0.9.0']
# jupyter_server_ydoc -> ypy-websocket[version='>=0.8.2,<0.9.0']
#
# Package pyqtwebengine conflicts for:
# _anaconda_depends -> spyder -> pyqtwebengine[version='<5.16|>=5.15,<5.16']
# spyder -> pyqtwebengine[version='<5.16|>=5.15,<5.16']
#
# Package harfbuzz conflicts for:
# pango -> harfbuzz[version='>=2.6.0|>=4.3.0,<5.0a0']
# graphviz -> pango[version='>=1.50.7,<2.0a0'] -> harfbuzz[version='>=2.6.0|>=4.3.0,<5.0a0']
#
# Package aiofiles conflicts for:
# ypy-websocket -> aiofiles[version='>=22.1.0,<23']
# jupyter_server_ydoc -> ypy-websocket[version='>=0.8.2,<0.9.0'] -> aiofiles[version='>=22.1.0,<23']
#
# Package glob2 conflicts for:
# _anaconda_depends -> glob2
# conda-build -> glob2[version='>=0.6']
#
# Package scikit-image conflicts for:
# _anaconda_depends -> scikit-image
# datashader -> scikit-image
#
# Package werkzeug conflicts for:
# _anaconda_depends -> werkzeug
# flask -> werkzeug[version='>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2|>=0.7,<1.0.0']
# _anaconda_depends -> flask -> werkzeug[version='>=0.15|>=0.15,<2.0|>=2.0|>=2.2.2|>=0.7,<1.0.0']
#
# Package pexpect conflicts for:
# _anaconda_depends -> spyder -> pexpect[version='>=4.4.0']
# spyder -> pexpect[version='>=4.4.0']
# _anaconda_depends -> pexpect
#
# Package responses conflicts for:
# datasets -> responses[version='<0.19']
# transformers -> datasets!=2.5.0 -> responses[version='<0.19']
#
# Package utf8proc conflicts for:
# arrow-cpp -> utf8proc
# pyarrow -> arrow-cpp[version='>=11.0.0,<11.0.1.0a0'] -> utf8proc
#
# Package atomicwrites conflicts for:
# _anaconda_depends -> atomicwrites
# _anaconda_depends -> pytest -> atomicwrites[version='>=1.0|>=1.2.0']
# pytest -> atomicwrites[version='>=1.0']
# astropy -> pytest[version='<4'] -> atomicwrites[version='>=1.0']
# spyder -> atomicwrites[version='>=1.2.0']
#
# Package anaconda-client conflicts for:
# _anaconda_depends -> anaconda-navigator -> anaconda-client[version='>=1.6|>=1.6.12|>=1.6.14']
# conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda-navigator==2.5.1 -> anaconda-client[version='>=1.6.14']
# anaconda-project -> anaconda-client
# anaconda-navigator==2.5.1 -> conda-repo-cli -> anaconda-client[version='>=1.7.2']
# _anaconda_depends -> anaconda-client
#
# Package sphinxcontrib-jsmath conflicts for:
# sphinx -> sphinxcontrib-jsmath
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-jsmath
# numpydoc -> sphinx[version='>=4.2'] -> sphinxcontrib-jsmath
# _anaconda_depends -> sphinxcontrib-jsmath
#
# Package tldextract conflicts for:
# _anaconda_depends -> tldextract
# scrapy -> tldextract
#
# Package mpc conflicts for:
# _anaconda_depends -> mpc
# _anaconda_depends -> gmpy2 -> mpc[version='>=1.1.0,<2.0a0']
#
# Package sympy conflicts for:
# _anaconda_depends -> sympy
# transformers -> pytorch -> sympy
#
# Package paramiko conflicts for:
# _anaconda_depends -> paramiko
# _anaconda_depends -> spyder -> paramiko[version='>=2.4.0']
# spyder -> paramiko[version='>=2.4.0']
#
# Package pytables conflicts for:
# _anaconda_depends -> blaze -> pytables[version='>=3.0.0']
# _anaconda_depends -> pytables
#
# Package sphinxcontrib-qthelp conflicts for:
# sphinx -> sphinxcontrib-qthelp
# _anaconda_depends -> sphinxcontrib-qthelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-qthelp
# numpydoc -> sphinx[version='>=4.2'] -> sphinxcontrib-qthelp
#
# Package m2w64-gcc-libs conflicts for:
# glib -> libffi[version='>=3.2.1,<3.3a0'] -> m2w64-gcc-libs
# terminado -> pywinpty -> m2w64-gcc-libs
# libffi -> m2w64-gcc-libs
# pywinpty -> m2w64-gcc-libs
# jupyter_server -> pywinpty -> m2w64-gcc-libs
# _anaconda_depends -> m2w64-gcc-libs
#
# Package m2-msys2-runtime conflicts for:
# conda-build -> m2-patch[version='>=2.6'] -> m2-msys2-runtime
# m2-patch -> m2-msys2-runtime
#
# Package google-cloud-core conflicts for:
# _anaconda_depends -> google-cloud-storage -> google-cloud-core[version='>=1.2.0,<2.0dev|>=1.4.1,<2.0dev|>=1.6.0,<3.0dev|>=2.3.0,<3.0dev|>=1.6.1,<2.0dev']
# _anaconda_depends -> google-cloud-core
#
# Package pydantic conflicts for:
# anaconda-cloud-auth -> pydantic[version='<2.0']
# anaconda-navigator==2.5.1 -> anaconda-cloud-auth[version='>=0.1.3'] -> pydantic[version='<2.0']
#
# Package gtest conflicts for:
# grpc-cpp -> abseil-cpp[version='>=20230802.0,<20230802.1.0a0'] -> gtest[version='>=1.14.0,<1.14.1.0a0']
# abseil-cpp -> gtest[version='>=1.14.0,<1.14.1.0a0']
#
# Package pep8-naming conflicts for:
# anaconda-cloud-auth -> pyjwt -> pep8-naming
# pyjwt -> pep8-naming
#
# Package semver conflicts for:
# anaconda-cloud-auth -> semver[version='<3']
# anaconda-navigator==2.5.1 -> anaconda-cloud-auth[version='>=0.1.3'] -> semver[version='<3']
#
# Package pylint-venv conflicts for:
# _anaconda_depends -> spyder -> pylint-venv[version='>=2.1.1']
# spyder -> pylint-venv[version='>=2.1.1']
#
# Package py-cpuinfo conflicts for:
# pytables -> py-cpuinfo
# _anaconda_depends -> pytables -> py-cpuinfo
#
# Package navigator-updater conflicts for:
# _anaconda_depends -> navigator-updater
# anaconda-navigator==2.5.1 -> navigator-updater
#
# Package flask conflicts for:
# _anaconda_depends -> blaze -> flask[version='>=0.10.1|>=0.9']
# _anaconda_depends -> flask
#
# Package conda-token conflicts for:
# _anaconda_depends -> conda-token
# anaconda-navigator==2.5.1 -> conda-token
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining pytesseract:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__win==0=0:  20%|##        | 1/5 [00:00<00:00, 15.88it/s]
# Examining @/win-64::__archspec==1=x86_64:  40%|####      | 2/5 [00:00<00:00, 31.76it/s]
# Examining python=3.11:  60%|######    | 3/5 [00:00<00:00, 47.64it/s]
# Examining @/win-64::__cuda==12.3=0:  80%|########  | 4/5 [00:00<00:00, 17.77it/s]
# Examining @/win-64::__cuda==12.3=0: 100%|##########| 5/5 [00:00<00:00, 22.21it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for pytesseract python:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - pytesseract -> python[version='2.7.*|3.5.*|3.6.*']
#
# Your python: python=3.11
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
import pytesseract
import cv2 # For loading image

img = cv2.imread('download.jpg')
text = pytesseract.image_to_string(
    img, config='-l eng --oem 1 --psm 6'
)
print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pytesseract
#       2 import cv2 # For loading image
#       4 img = cv2.imread('download.jpg')
#
# ModuleNotFoundError: No module named 'pytesseract'
